# %% [markdown]
# data[1]['Data'][0]['FK_Periodo']
#
# data[1]['Data'][0]['Anyo']
#
# data[1]['Data'][0]['Valor']

# %%
import requests
import pandas as pd
# Out:
# c:\Users\fabih\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.3)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
url = "https://servicios.ine.es/wstempus/js/ES/DATOS_TABLA/50902?p=12"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 52

# %%
data[0]
# Out:
# {'COD': 'IPC251852',
#  'Nombre': 'Nacional. Índice general. Índice. ',
#  'FK_Unidad': 133,
#  'FK_Escala': 1,
#  'Notas': [{'texto': 'https://www.ine.es/dyngs/INEbase/es/operacion.htm?c=Estadistica_C&cid=1254736176802&menu=ultiDatos&idp=1254735976607#~#https://www.ine.es/consul/serie.do?s=IPC206446&nult=100&TB_iframe=true&position=center&width=700&height=500&L=0&nocab=1 ',
#    'Fk_TipoNota': 6,
#    'textoTipo': None}],
#  'Data': [{'Fecha': 1764543600000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 12,
#    'Anyo': 2025,
#    'Valor': 119.942,
#    'Secreto': False},
#   {'Fecha': 1761951600000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 11,
#    'Anyo': 2025,
#    'Valor': 119.532,
#    'Secreto': False},
#   {'Fecha': 1759269600000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 10,
#    'Anyo': 2025,
#    'Valor': 119.301,
#    'Secreto': False},
#   {'Fecha': 1756677600000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 9,
#    'Anyo': 2025,
#    'Valor': 118.485,
#    'Secreto': False},
# ...

# %%
data[0].keys()
# Out:
# dict_keys(['COD', 'Nombre', 'FK_Unidad', 'FK_Escala', 'Notas', 'Data'])

# %%
data[4]['Nombre']
# Out:
# 'Nacional. Alimentos y bebidas no alcohólicas. Índice. '

# %%
data[1]['Data'][0]['FK_Periodo']   #Ruta que nos lleva al mes
# Out:
# 12

# %%
data[1]['Data'][0]['Anyo'] #Ruta que nos lleva al año
# Out:
# 2025

# %%
data[1]['Data'][0]['Valor'] #Ruta que lleva al valor (IPC)
# Out:
# 0.3

# %%
data[3]['FK_Escala']
# Out:
# 1

# %%
for serie in data:     
    print(f'{'=' * 100}\n-Tipo de dato: {serie['Nombre']}\n-Mes en numero: {data[1]['Data'][0]['FK_Periodo']}\n-Año: {data[1]['Data'][0]['Anyo']}\n-IPC(%): {data[1]['Data'][0]['Valor']}\n{'=' * 100}')
# Out:
# ...
# -Tipo de dato: Nacional. Índice general. Índice.
# -Mes en numero: 12
# -Año: 2025
# -IPC(%): 0.3
# ...
# -Tipo de dato: Nacional. Índice general. Variación mensual.
# -Mes en numero: 12
# -Año: 2025
# -IPC(%): 0.3
# ...
# -Tipo de dato: Nacional. Índice general. Variación anual.
# -Mes en numero: 12
# -Año: 2025
# -IPC(%): 0.3
# ...
# -Tipo de dato: Nacional. Índice general. Variación en lo que va de año.
# -Mes en numero: 12
# -Año: 2025
# -IPC(%): 0.3
# ...
# -Tipo de dato: Nacional. Alimentos y bebidas no alcohólicas. Índice.
# -Mes en numero: 12
# -Año: 2025
# -IPC(%): 0.3
# ...
# -Tipo de dato: Nacional. Alimentos y bebidas no alcohólicas. Variación mensual.
# -Mes en numero: 12
# -Año: 2025
# -IPC(%): 0.3
# ...
# -Tipo de dato: Nacional. Alimentos y bebidas no alcohólicas. Variación anual.
# -Mes en numero: 12
# -Año: 2025
# -IPC(%): 0.3
# ...
# -Tipo de dato: Nacional. Alimentos y bebidas no alcohólicas. Variación en lo que va de año.
# -Mes en numero: 12
# -Año: 2025
# -IPC(%): 0.3
# ...

# %%
for serie in datos_grupos:     
    nombre = serie['Nombre']     
    ultimo_valor = serie['Data'][0]['Valor']     
    anyo = serie['Data'][0]['Anyo']     
    print(f"{nombre}: {ultimo_valor}% ({anyo})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 for serie in datos_grupos:
#       2     nombre = serie['Nombre']
#       3     ultimo_valor = serie['Data'][0]['Valor']
#
# NameError: name 'datos_grupos' is not defined
